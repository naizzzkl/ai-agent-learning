# %% [markdown]
# # 我的第一个 AI 调用项目
#
# - **日期**：2026-03-18
# - **目的**：学习调用大模型 API，为后续智能体项目打基础
# - **使用的模型**：DeepSeek Chat
# - **作者**：nai
#
# ## 说明
# 本笔记本演示了如何使用 Python 调用 DeepSeek API，并观察不同问题的回答。

# %%
# 安装 openai（兼容DeepSeek）、python-dotenv、requests
# !pip install python-dotenv requests -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# 加载 .env 文件中的环境变量
load_dotenv()

# 从环境变量中读取 API 密钥
api_key = os.getenv("DEEPSEEK_API_KEY")

# 初始化 OpenAI 客户端（指向 DeepSeek 的接口）
client = OpenAI(
    api_key=api_key,
    base_url="https://api.deepseek.com/v1"   # DeepSeek 的 API 地址
)

# 发送请求
response = client.chat.completions.create(
    model="deepseek-chat",                    # DeepSeek 的模型名称
    messages=[
        {"role": "system", "content": "资深python程序员"},
        {"role": "user", "content": "向我表白一下"}
    ],
    #model=deepseek-v3.2,
    temperature=0.1, #创造力控制（0-1）
    max_tokens=150, #输出长度限制
    top_p=0.95, #核心词采样阈值
    frequency_penalty=0.3 #重复抑制系数
)

# 打印回复
print(" 说：", response.choices[0].message.content)
# Out:
#  说： （双眼放光，双手紧张地搓着衣角）那个...我...我喜欢你很久了！每天早上给你带早餐的时候，看到你吃我做的三明治的样子，我就觉得特别幸福...（声音越来越小）虽然你可能不记得，但我已经默默关注你三年两个月零五天了...

# %%
# 在当前目录创建 .gitignore 文件
with open('.gitignore', 'w') as f:
    f.write('.env\n')           # 忽略 .env 文件
    f.write('__pycache__/\n')   # 忽略 Python 缓存文件夹
    f.write('*.ipynb_checkpoints/\n')  # 忽略 Jupyter 自动备份
    f.write('.DS_Store\n')       # 忽略 Mac 系统文件

# %%
# !git --version
# Out:
# git version 2.53.0.windows.2

# %%
# !git config --global user.name "naizzzkl"
# !git config --global user.email "naizzzkl@outlook.com"

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/naizz/ai_first_call/.git/

# %%
# !git add .

# %%
# !git commit -m "first commit: 成功调用 DeepSeek API"
# Out:
# [main (root-commit) 87ab395] first commit: 鎴愬姛璋冪敤 DeepSeek API
#  2 files changed, 163 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 Untitled.ipynb

# %%
response = client.chat.completions.create(...)
print("本次使用 token 数：", response.usage.total_tokens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 response = client.chat.completions.create(...)
#       2 print("本次使用 token 数：", response.usage.total_tokens)
#
# NameError: name 'client' is not defined

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com/v1"
)

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "你是一个乐于助人的助手。"},
        {"role": "user", "content": "请用一句话介绍什么是人工智能智能体（Agent）？"}
    ],
    temperature=0.7,
    max_tokens=150
)

print("AI 说：", response.choices[0].message.content)
print("本次使用 token 数：", response.usage.total_tokens)
# Out:
# AI 说： 人工智能智能体是一种能够感知环境、自主决策并执行任务以实现特定目标的智能系统。
# 本次使用 token 数： 42
